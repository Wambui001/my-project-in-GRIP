# %% [markdown]
# # Task 4 EXPLORATORY DATA ANALYSIS USING PYTHON

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df['eventid'].unique()
df['iyear'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: iyear, dtype: int64

# %%
print(df.columns)
df['iyear'].dtype
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)
# dtype('int64')

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['iyear'],data=df)
plt.xticks(rotation=90)
plt.title('Terrorist Attacks Over the Years')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['country_txt'],data= df,order=df['country_txt'].value_counts().index[:10])
plt.xticks(rotation=90)
plt.title('Top 10 Countries with Most Terrorist Attacks ')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='attacktype1_txt',data=df,order=df['attacktype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Types of Terrorist Attacks ')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='weaptype1_txt',data=df,order=df['weaptype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Types of Weapons Used in Attacks')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['iyear'],data=df)
plt.xticks(rotation=90)
plt.title('Terrorist Attacks Over the Years')
plt.savefig('terrorist_attacks_over_years.png')

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['country_txt'],data= df,order=df['country_txt'].value_counts().index[:10])
plt.xticks(rotation=90)
plt.title('Top 10 Countries with Most Terrorist Attacks ')
plt.savefig('top_10_countries_with_terrorist_attacks.png')

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='attacktype1_txt',data=df,order=df['attacktype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Types of Terrorist Attacks ')
plt.savefig('types_of_terrorist_attacks.png')

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='weaptype1_txt',data=df,order=df['weaptype1_txt'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Types of Weapons Used in Attacks')
plt.savefig('types_of_weapons.png')
